# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

crime = pd.read_csv("crime.csv", low_memory=False)
"""
numCrimes = crime["Neighborhood"].value_counts()
print(numCrimes)
"""
# Define the list of neighborhoods you care about
target_neighborhoods = [
    "East Liberty",
    "Upper Lawrenceville",
    "Parkway East",
    "Glassport High Street",
    "North Braddock",
    "Pittsburgh",
    "Upper Liberty",
    "Harrison Township",
    "Avalon",
    "Clairton",
    "Central Lawrenceville",
    "South Fayette",
    "Squirrel Hill South",
    "Beechview",
    "South Side Slopes",
    "Highland Park",
    "Sheraden",
    "Beltzhoover",
    "Allegheny Center",
    "Crawford-Roberts",
    "Elliott",
    "South Oakland"
]

# Filter the DataFrame
filtered_crimes = crime[crime["Neighborhood"].isin(target_neighborhoods)]

# Get number of crimes per neighborhood
numCrimes_filtered = filtered_crimes["Neighborhood"].value_counts()

print(numCrimes_filtered)
# Out:
# Neighborhood
# East Liberty             1913
# Squirrel Hill South      1352
# Crawford-Roberts         1061
# Sheraden                 1042
# South Side Slopes         794
# Beechview                 781
# Central Lawrenceville     654
# Highland Park             653
# South Oakland             584
# Allegheny Center          576
# Elliott                   484
# Beltzhoover               413
# Upper Lawrenceville       272
# Name: count, dtype: int64

# %%
plt.bar(site_air_quality['site'], site_air_quality['air_quality_score'], color='skyblue')
plt.xticks(rotation=45, ha='right')
plt.title('Average Air Quality Score by Monitoring Site')
plt.xlabel('Monitoring Site (Neighborhood Area)')
plt.ylabel('Air Quality Score (1 = Best)')
plt.show()
